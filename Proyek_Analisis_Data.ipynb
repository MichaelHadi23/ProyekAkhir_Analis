# %% [markdown]
# <a href="https://colab.research.google.com/github/MichaelHadi23/ProyekAkhir_Analis/blob/main/Proyek_Analisis_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** [ MICHAEL HADI HARTO WIJAYA]
# - **Email:** [michaelhadi749@gmail.com]
# - **ID Dicoding:** [Michael Hadi]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# 1. Bagaimana distribusi total penggunaan sepeda per tahun?
# 2. Bagaimana penggunaan sepeda bervariasi di antara musim yang berbeda? Musim apa yang memiliki penggunaan sepeda terbanyak?
# 3. Bagaimana penggunaan sepeda bervariasi di antara kondisi cuaca yang berbeda? Kondisi cuaca apa yang paling memengaruhi penggunaan sepeda?
# 4. Apakah ada perbedaan dalam jam puncak penggunaan sepeda antara hari kerja dan akhir pekan?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
day_df  = pd.read_csv("https://raw.githubusercontent.com/MichaelHadi23/ProyekAkhir_Analis/main/day.csv")
day_df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0             2  0.344167  0.363625  0.805833   0.160446     331         654
# 1             2  0.363478  0.353739  0.696087   0.248539     131         670
# 2             1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3             1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4             1  0.226957  0.229270  0.436957   0.186900      82        1518
# ..          ...       ...       ...       ...        ...     ...         ...
# 726           2  0.254167  0.226642  0.652917   0.350133     247        1867
# 727           2  0.253333  0.255046  0.590000   0.155471     644        2451
# 728           2  0.253333  0.242400  0.752917   0.124383     159        1182
# 729           1  0.255833  0.231700  0.483333   0.350754     364        1432
# 730           2  0.215833  0.223487  0.577500   0.154846     439        2290
#
#       cnt
# 0     985
# 1     801
# 2    1349
# 3    1562
# 4    1600
# ..    ...
# 726  2114
# 727  3095
# 728  1341
# 729  1796
# 730  2729
#
# [731 rows x 16 columns]

# %%
hour_df = pd.read_csv("https://raw.githubusercontent.com/MichaelHadi23/ProyekAkhir_Analis/main/hour.csv")
hour_df
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# 1               0           1  0.22  0.2727  0.80     0.0000       8
# 2               0           1  0.22  0.2727  0.80     0.0000       5
# 3               0           1  0.24  0.2879  0.75     0.0000       3
# 4               0           1  0.24  0.2879  0.75     0.0000       0
# ...           ...         ...   ...     ...   ...        ...     ...
# 17374           1           2  0.26  0.2576  0.60     0.1642      11
# 17375           1           2  0.26  0.2576  0.60     0.1642       8
# 17376           1           1  0.26  0.2576  0.60     0.1642       7
# 17377           1           1  0.26  0.2727  0.56     0.1343      13
# 17378           1           1  0.26  0.2727  0.65     0.1343      12
#
#        registered  cnt
# 0              13   16
# 1              32   40
# 2              27   32
# 3              10   13
# 4               1    1
# ...           ...  ...
# 17374         108  119
# 17375          81   89
# 17376          83   90
# 17377          48   61
# 17378          37   49
#
# [17379 rows x 17 columns]

# %% [markdown]
# ### Assessing Data

# %%
# !pip install pandas
import pandas as pd

# Assuming your bike data is in a CSV file named 'bike.csv' in the same location as your notebook
bike_df = pd.read_csv("https://raw.githubusercontent.com/MichaelHadi23/ProyekAkhir_Analis/main/hour.csv")

# Now you can use bike_df
bike_df.info()
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
print("Jumlah duplikasi data : ", bike_df.duplicated().sum())
# Out:
# Jumlah duplikasi data :  0

# %%
bike_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# std        0.167165      2.005771      0.465431      0.639357      0.192556
# min        0.000000      0.000000      0.000000      1.000000      0.020000
# 25%        0.000000      1.000000      0.000000      1.000000      0.340000
# 50%        0.000000      3.000000      1.000000      1.000000      0.500000
# 75%        0.000000      5.000000      1.000000      2.000000      0.660000
# max        1.000000      6.000000      1.000000      4.000000      1.000000
#
#               atemp           hum     windspeed        casual    registered  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.475775      0.627229      0.190098     35.676218    153.786869
# std        0.171850      0.192930      0.122340     49.305030    151.357286
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.333300      0.480000      0.104500      4.000000     34.000000
# 50%        0.484800      0.630000      0.194000     17.000000    115.000000
# 75%        0.621200      0.780000      0.253700     48.000000    220.000000
# max        1.000000      1.000000      0.850700    367.000000    886.000000
#
#                 cnt
# count  17379.000000
# mean     189.463088
# std      181.387599
# min        1.000000
# 25%       40.000000
# 50%      142.000000
# 75%      281.000000
# max      977.000000

# %% [markdown]
# ##HOUR

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
hour_df.nunique()
# Out:
# instant       17379
# dteday          731
# season            4
# yr                2
# mnth             12
# hr               24
# holiday           2
# weekday           7
# workingday        2
# weathersit        4
# temp             50
# atemp            65
# hum              89
# windspeed        30
# casual          322
# registered      776
# cnt             869
# dtype: int64

# %%
print("Jumlah Duplikasi: ", day_df.duplicated().sum())
# Out:
# Jumlah Duplikasi:  0

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# std        0.167165      2.005771      0.465431      0.639357      0.192556
# min        0.000000      0.000000      0.000000      1.000000      0.020000
# 25%        0.000000      1.000000      0.000000      1.000000      0.340000
# 50%        0.000000      3.000000      1.000000      1.000000      0.500000
# 75%        0.000000      5.000000      1.000000      2.000000      0.660000
# max        1.000000      6.000000      1.000000      4.000000      1.000000
#
#               atemp           hum     windspeed        casual    registered  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.475775      0.627229      0.190098     35.676218    153.786869
# std        0.171850      0.192930      0.122340     49.305030    151.357286
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.333300      0.480000      0.104500      4.000000     34.000000
# 50%        0.484800      0.630000      0.194000     17.000000    115.000000
# 75%        0.621200      0.780000      0.253700     48.000000    220.000000
# max        1.000000      1.000000      0.850700    367.000000    886.000000
#
#                 cnt
# count  17379.000000
# mean     189.463088
# std      181.387599
# min        1.000000
# 25%       40.000000
# 50%      142.000000
# 75%      281.000000
# max      977.000000

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Karena pada Assessing Data, data tidak ada masalah sehingga tidak perlu dilakukan cleaning data dan dilanjutkan pada langkah selanjutnya.

# %%
day_df.rename(columns={'yr': 'year', 'mnth': 'month', 'weathersit': 'weather_situation',
                       'atemp': 'temp_feel', 'hum': 'humidity', 'cnt': 'Total'}, inplace=True)

# %% [markdown]
# ##Menghapus kolom

# %%
day_df.drop(['holiday','instant'], axis=1, inplace=True)

# %% [markdown]
# ##Mengubah tipe data kolom

# %%
datetime_columns = ["dteday"]

for column in datetime_columns:
    day_df[column] = pd.to_datetime(day_df[column])

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   dteday             731 non-null    datetime64[ns]
#  1   season             731 non-null    int64
#  2   year               731 non-null    int64
#  3   month              731 non-null    int64
#  4   weekday            731 non-null    int64
#  5   workingday         731 non-null    int64
#  6   weather_situation  731 non-null    int64
#  7   temp               731 non-null    float64
#  8   temp_feel          731 non-null    float64
#  9   humidity           731 non-null    float64
#  10  windspeed          731 non-null    float64
#  11  casual             731 non-null    int64
#  12  registered         731 non-null    int64
#  13  Total              731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(9)
# memory usage: 80.1 KB

# %% [markdown]
# ##Mengubah nama kolom untuk memudahkan dalam membaca data

# %%
def change_season(x):
    if x == 1:
        return 'Springer'
    elif x == 2:
        return 'Summer'
    elif x == 3:
        return 'Fall'
    else:
        return 'Winter'


day_df['season'] = day_df['season'].apply(change_season)
day_df.sample(5)
# Out:
#         dteday  season  year  month  weekday  workingday  weather_situation  \
# 343 2011-12-10  Winter     0     12        6           0                  1
# 603 2012-08-26    Fall     1      8        0           0                  2
# 106 2011-04-17  Summer     0      4        0           0                  1
# 687 2012-11-18  Winter     1     11        0           0                  1
# 664 2012-10-26  Winter     1     10        5           1                  2
#
#          temp  temp_feel  humidity  windspeed  casual  registered  Total
# 343  0.275000   0.266412  0.507500   0.233221     502        2688   3190
# 603  0.653333   0.595996  0.845833   0.228858    1483        3772   5255
# 106  0.456667   0.445696  0.479583   0.303496    1558        2186   3744
# 687  0.342500   0.337746  0.692917   0.227612     922        3747   4669
# 664  0.545833   0.522750  0.807083   0.132467    1182        6262   7444

# %%
#Mengubah kolom month##

month_change = {1: 'January', 2: 'February', 3: 'March',
                4:'April',5:'May',6:'June',7:'July',
                8:'August',9:'September',10:'October',11:'November',12:'December'}
day_df['month'] = day_df['month'].map(month_change)

day_df.sample(5)
# Out:
#         dteday  season  year      month  weekday  workingday  \
# 195 2011-07-15    Fall     0       July        5           1
# 296 2011-10-24  Winter     0    October        1           1
# 567 2012-07-21    Fall     1       July        6           0
# 630 2012-09-22    Fall     1  September        6           0
# 137 2011-05-18  Summer     0        May        3           1
#
#      weather_situation      temp  temp_feel  humidity  windspeed  casual  \
# 195                  1  0.663333   0.624371  0.591250   0.182833    1318
# 296                  1  0.463333   0.457067  0.772083   0.118792     699
# 567                  3  0.595833   0.549912  0.865417   0.213300    1264
# 630                  1  0.650000   0.610488  0.646667   0.283583    2512
# 137                  2  0.550000   0.527158  0.870000   0.201492     536
#
#      registered  Total
# 195        4220   5538
# 296        3488   4187
# 567        3195   4459
# 630        5883   8395
# 137        3319   3855

# %%
#Mengubah kolom weekday##

weekday_change = {0: 'Monday', 1: 'Tuesday', 2: 'Wednesday',
                  3: 'Thursday', 4: 'Friday', 5: 'Saturday', 6: 'Sunday'}
day_df['weekday'] = day_df['weekday'].map(weekday_change)

day_df.sample(5)
# Out:
#         dteday  season  year      month    weekday  workingday  \
# 293 2011-10-21  Winter     0    October   Saturday           1
# 262 2011-09-20    Fall     0  September  Wednesday           1
# 642 2012-10-04  Winter     1    October     Friday           1
# 694 2012-11-25  Winter     1   November     Monday           0
# 566 2012-07-20    Fall     1       July   Saturday           1
#
#      weather_situation      temp  temp_feel  humidity  windspeed  casual  \
# 293                  1  0.427500   0.423596  0.574167   0.221396     676
# 262                  2  0.561667   0.532217  0.881250   0.134954     438
# 642                  2  0.657500   0.607975  0.722917   0.117546     891
# 694                  1  0.245833   0.257583  0.468333   0.150500     309
# 566                  2  0.665833   0.613025  0.844167   0.208967     747
#
#      registered  Total
# 293        3628   4304
# 262        3203   3641
# 642        6437   7328
# 694        2115   2424
# 566        5123   5870

# %% [markdown]
# #### Hour Data

# %%
##Mengubah nama kolom untuk memudahkan
hour_df.rename(columns={'yr': 'year', 'mnth': 'month', 'hr':'hour', 'weathersit': 'weather_situation',
                       'atemp': 'temp_feel', 'hum': 'humidity', 'cnt': 'Total'}, inplace=True)
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   instant            17379 non-null  int64
#  1   dteday             17379 non-null  object
#  2   season             17379 non-null  int64
#  3   year               17379 non-null  int64
#  4   month              17379 non-null  int64
#  5   hour               17379 non-null  int64
#  6   holiday            17379 non-null  int64
#  7   weekday            17379 non-null  int64
#  8   workingday         17379 non-null  int64
#  9   weather_situation  17379 non-null  int64
#  10  temp               17379 non-null  float64
#  11  temp_feel          17379 non-null  float64
#  12  humidity           17379 non-null  float64
#  13  windspeed          17379 non-null  float64
#  14  casual             17379 non-null  int64
#  15  registered         17379 non-null  int64
#  16  Total              17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
##Menghapus kolom holiday

hour_df.drop(['holiday'], axis=1, inplace=True)

# %%
#Mengubah tipe data kolom
for column in datetime_columns:
    hour_df[column] = pd.to_datetime(hour_df[column])

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   instant            17379 non-null  int64
#  1   dteday             17379 non-null  datetime64[ns]
#  2   season             17379 non-null  int64
#  3   year               17379 non-null  int64
#  4   month              17379 non-null  int64
#  5   hour               17379 non-null  int64
#  6   weekday            17379 non-null  int64
#  7   workingday         17379 non-null  int64
#  8   weather_situation  17379 non-null  int64
#  9   temp               17379 non-null  float64
#  10  temp_feel          17379 non-null  float64
#  11  humidity           17379 non-null  float64
#  12  windspeed          17379 non-null  float64
#  13  casual             17379 non-null  int64
#  14  registered         17379 non-null  int64
#  15  Total              17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 2.1 MB

# %%
##Mengubah kolom season
hour_df['season'] = hour_df['season'].apply(change_season)

hour_df.sample(5)
# Out:
#        instant     dteday    season  year  month  hour  weekday  workingday  \
# 15361    15362 2012-10-07    Winter     1     10     6        0           0
# 10907    10908 2012-04-04    Summer     1      4    15        3           1
# 12098    12099 2012-05-24    Summer     1      5     7        4           1
# 3638      3639 2011-06-05    Summer     0      6    12        0           0
# 10534    10535 2012-03-20  Springer     1      3     1        2           1
#
#        weather_situation  temp  temp_feel  humidity  windspeed  casual  \
# 15361                  2  0.44     0.4394      0.54     0.1940       4
# 10907                  2  0.64     0.6212      0.44     0.2836      86
# 12098                  1  0.60     0.5606      0.83     0.1045      22
# 3638                   2  0.64     0.6061      0.69     0.1045     123
# 10534                  1  0.54     0.5152      0.88     0.0000       6
#
#        registered  Total
# 15361          19     23
# 10907         182    268
# 12098         393    415
# 3638          212    335
# 10534           9     15

# %%
#mengubah kolom year
hour_df['year'] = hour_df['year'].apply(change_year)

hour_df.sample(5)
# Out:
#        instant     dteday    season year  month  hour  weekday  workingday  \
# 16109    16110 2012-11-08    Winter    1     11    23        4           1
# 15115    15116 2012-09-27    Winter    1      9     0        4           1
# 8001      8002 2011-12-05    Winter    0     12     1        1           1
# 1605      1606 2011-03-12  Springer    0      3     9        6           0
# 8765      8766 2012-01-06  Springer    1      1     1        5           1
#
#        weather_situation  temp  temp_feel  humidity  windspeed  casual  \
# 16109                  1  0.34     0.3030      0.46     0.3582       5
# 15115                  1  0.60     0.5758      0.78     0.0896       5
# 8001                   1  0.32     0.3485      0.87     0.0000       2
# 1605                   1  0.28     0.2879      0.65     0.1045      25
# 8765                   1  0.22     0.2727      0.75     0.0000       2
#
#        registered  Total
# 16109          82     87
# 15115          60     65
# 8001           10     12
# 1605           76    101
# 8765            6      8

# %%
##Mengubah kolom working day
def change_wd(x):
    if x == 0:
        return 'Holiday'
    elif x == 1:
        return 'Working Day'
    else:
        return 'Unknown'

hour_df['workingday'] = hour_df['workingday'].apply(change_wd)

hour_df.sample(5)
# Out:
#        instant     dteday    season year  month  hour  weekday   workingday  \
# 7361      7362 2011-11-08    Winter    0     11     8        2  Working Day
# 1509      1510 2011-03-08  Springer    0      3     6        2  Working Day
# 10686    10687 2012-03-26    Summer    1      3     9        1  Working Day
# 1286      1287 2011-02-26  Springer    0      2    18        6      Holiday
# 389        390 2011-01-17  Springer    0      1    17        1      Holiday
#
#        weather_situation  temp  temp_feel  humidity  windspeed  casual  \
# 7361                   1  0.32     0.3333      0.93     0.1045      11
# 1509                   1  0.20     0.2576      0.59     0.0000       3
# 10686                  1  0.46     0.4545      0.47     0.2836      37
# 1286                   1  0.34     0.3333      0.46     0.1940      26
# 389                    1  0.20     0.1970      0.51     0.1940       4
#
#        registered  Total
# 7361          455    466
# 1509           42     45
# 10686         245    282
# 1286          111    137
# 389            67     71

# %%
##Mengubah kolom weater
def change_ws(x):
    if x == 1:
        return 'Clear'
    elif x == 2:
        return 'Mist + Cloudy'
    elif x == 3:
        return 'Light Snow/Rain'
    elif x == 4:
        return 'Heavy Rain/Snow/Ice Pallets'
    else:
        return 'Unknown'

hour_df['weather_situation'] = hour_df['weather_situation'].apply(change_ws)

hour_df.sample(5)
# Out:
#       instant     dteday    season year  month  hour  weekday   workingday  \
# 7233     7234 2011-11-03    Winter    0     11     0        4  Working Day
# 1359     1360 2011-03-01  Springer    0      3    22        2  Working Day
# 6366     6367 2011-09-27    Winter    0      9    20        2  Working Day
# 8210     8211 2011-12-13    Winter    0     12    18        2  Working Day
# 6702     6703 2011-10-11    Winter    0     10    20        2  Working Day
#
#      weather_situation  temp  temp_feel  humidity  windspeed  casual  \
# 7233             Clear  0.36     0.3636      0.76     0.0896       3
# 1359             Clear  0.24     0.2727      0.62     0.1045       3
# 6366             Clear  0.62     0.5909      0.78     0.0000      17
# 8210             Clear  0.34     0.3182      0.42     0.2239      12
# 6702     Mist + Cloudy  0.58     0.5455      0.83     0.2239      31
#
#       registered  Total
# 7233          28     31
# 1359          44     47
# 6366         221    238
# 8210         370    382
# 6702         203    234

# %%
##mengubah kolom month
hour_df['weather_situation'] = hour_df['weather_situation'].apply(change_ws)

hour_df.sample(5)
# Out:
#        instant     dteday    season year  month  hour  weekday   workingday  \
# 13653    13654 2012-07-28      Fall    1      7     2        6      Holiday
# 7395      7396 2011-11-09    Winter    0     11    18        3  Working Day
# 15514    15515 2012-10-13    Winter    1     10    15        6      Holiday
# 17174    17175 2012-12-23  Springer    1     12     9        0      Holiday
# 14639    14640 2012-09-07      Fall    1      9     4        5  Working Day
#
#       weather_situation  temp  temp_feel  humidity  windspeed  casual  \
# 13653           Unknown  0.72     0.6818      0.70     0.0000      14
# 7395            Unknown  0.44     0.4394      0.67     0.1045      21
# 15514           Unknown  0.50     0.4848      0.36     0.1940     251
# 17174           Unknown  0.20     0.2273      0.59     0.1045       7
# 14639           Unknown  0.62     0.5606      0.88     0.0000       1
#
#        registered  Total
# 13653          76     90
# 7395          387    408
# 15514         364    615
# 17174          49     56
# 14639           7      8

# %%
##mengubah kolom weekday
hour_df['weekday'] = hour_df['weekday'].map(weekday_change)

hour_df.sample(5)
# Out:
#        instant     dteday    season year  month  hour    weekday   workingday  \
# 10207    10208 2012-03-06  Springer    1      3     9  Wednesday  Working Day
# 849        850 2011-02-07  Springer    0      2    20    Tuesday  Working Day
# 7775      7776 2011-11-25    Winter    0     11    14   Saturday  Working Day
# 2789      2790 2011-05-01    Summer    0      5     3     Monday      Holiday
# 8324      8325 2011-12-18    Winter    0     12    12     Monday      Holiday
#
#       weather_situation  temp  temp_feel  humidity  windspeed  casual  \
# 10207           Unknown  0.22     0.2727      0.47     0.0000      11
# 849             Unknown  0.32     0.3333      0.70     0.1045       6
# 7775            Unknown  0.52     0.5000      0.39     0.2239     122
# 2789            Unknown  0.40     0.4091      0.82     0.1045       8
# 8324            Unknown  0.26     0.2576      0.60     0.2239      26
#
#        registered  Total
# 10207         222    233
# 849            82     88
# 7775          150    272
# 2789           15     23
# 8324          202    228

# %% [markdown]
# ##Exploratory Data Analysis

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ##Explore Day

# %%
day_df.sample(5)
# Out:
#         dteday    season  year  month  weekday  workingday  weather_situation  \
# 564 2012-07-18      Fall     1      7        3           1                  1
# 485 2012-04-30    Summer     1      4        1           1                  2
# 145 2011-05-26    Summer     0      5        4           1                  1
# 566 2012-07-20      Fall     1      7        5           1                  2
# 70  2011-03-12  Springer     0      3        6           0                  1
#
#          temp  temp_feel  humidity  windspeed  casual  registered  Total
# 564  0.793333   0.745583  0.577083   0.137442     799        4914   5713
# 485  0.464167   0.457696  0.570000   0.171638     665        4907   5572
# 145  0.708333   0.654688  0.677500   0.199642     758        3919   4677
# 566  0.665833   0.613025  0.844167   0.208967     747        5123   5870
# 70   0.329167   0.325750  0.594583   0.220775     724        1408   2132

# %%
day_df.describe(include='all')
# Out:
#                      dteday season        year       month     weekday  \
# count                   731    731  731.000000  731.000000  731.000000
# unique                  NaN      4         NaN         NaN         NaN
# top                     NaN   Fall         NaN         NaN         NaN
# freq                    NaN    188         NaN         NaN         NaN
# mean    2012-01-01 00:00:00    NaN    0.500684    6.519836    2.997264
# min     2011-01-01 00:00:00    NaN    0.000000    1.000000    0.000000
# 25%     2011-07-02 12:00:00    NaN    0.000000    4.000000    1.000000
# 50%     2012-01-01 00:00:00    NaN    1.000000    7.000000    3.000000
# 75%     2012-07-01 12:00:00    NaN    1.000000   10.000000    5.000000
# max     2012-12-31 00:00:00    NaN    1.000000   12.000000    6.000000
# std                     NaN    NaN    0.500342    3.451913    2.004787
#
#         workingday  weather_situation        temp   temp_feel    humidity  \
# count   731.000000         731.000000  731.000000  731.000000  731.000000
# unique         NaN                NaN         NaN         NaN         NaN
# top            NaN                NaN         NaN         NaN         NaN
# freq           NaN                NaN         NaN         NaN         NaN
# mean      0.683995           1.395349    0.495385    0.474354    0.627894
# min       0.000000           1.000000    0.059130    0.079070    0.000000
# 25%       0.000000           1.000000    0.337083    0.337842    0.520000
# 50%       1.000000           1.000000    0.498333    0.486733    0.626667
# 75%       1.000000           2.000000    0.655417    0.608602    0.730209
# max       1.000000           3.000000    0.861667    0.840896    0.972500
# std       0.465233           0.544894    0.183051    0.162961    0.142429
#
#          windspeed       casual   registered        Total
# count   731.000000   731.000000   731.000000   731.000000
# unique         NaN          NaN          NaN          NaN
# top            NaN          NaN          NaN          NaN
# freq           NaN          NaN          NaN          NaN
# mean      0.190486   848.176471  3656.172367  4504.348837
# min       0.022392     2.000000    20.000000    22.000000
# 25%       0.134950   315.500000  2497.000000  3152.000000
# 50%       0.180975   713.000000  3662.000000  4548.000000
# 75%       0.233214  1096.000000  4776.500000  5956.000000
# max       0.507463  3410.000000  6946.000000  8714.000000
# std       0.077498   686.622488  1560.256377  1937.211452

# %% [markdown]
# ##Jumlah Rental berdasarkan season dan working day

# %%
##jumlah rental berdasarkan season
day_df.groupby(by=["season", "workingday"]).agg({
    "dteday": "nunique",
    "casual": "sum",
    "registered": "sum",
    "Total": ["max", "min", "mean", "sum"]
})
# Out:
#                      dteday  casual registered Total                     \
#                     nunique     sum        sum   max   min         mean
# season   workingday
# Fall     0               57  107345     204711  8714  1115  5474.666667
#          1              131  118746     630327  8173  1842  5718.114504
# Springer 0               61   32400     105283  7836   605  2257.098361
#          1              120   28222     305443  6312   431  2780.541667
# Summer   0               56  105693     182283  8294   795  5142.428571
#          1              128   97829     532784  8362  1471  4926.664062
# Winter   0               57   71294     191260  8555   627  4606.210526
#          1              121   58488     520571  8156    22  4785.611570
#
#
#                         sum
# season   workingday
# Fall     0           312056
#          1           749073
# Springer 0           137683
#          1           333665
# Summer   0           287976
#          1           630613
# Winter   0           262554
#          1           579059

# %%
##jumlah rental berdasarkan hari
day_df.groupby(by="weekday").agg({
    "dteday": "nunique",
    "casual": "sum",
    "registered": "sum",
    "Total": ["max", "min", "mean", "sum"]
})
# Out:
#            dteday  casual registered Total
#           nunique     sum        sum   max   min         mean     sum
# weekday
# Friday        104   61460     423935  7804   431  4667.259615  485395
# Monday        105  140521     303506  8227   605  4228.828571  444027
# Saturday      104   78238     409552  8362  1167  4690.288462  487790
# Sunday        105  153852     323955  8714   627  4550.542857  477807
# Thursday      104   57319     415729  8173   441  4548.538462  473048
# Tuesday       105   70784     384719  7525    22  4338.123810  455503
# Wednesday     104   57843     411266  7767   683  4510.663462  469109

# %%
##jumlah rental weather situasion
day_df.groupby(by="weather_situation").agg({
    "dteday": "nunique",
    "casual": "sum",
    "registered": "sum",
    "Total": ["max", "min", "mean", "sum"]
})
# Out:
#                    dteday  casual registered Total
#                   nunique     sum        sum   max  min         mean      sum
# weather_situation
# 1                     463  446346    1811606  8714  431  4876.786177  2257952
# 2                     247  169776     827082  8362  605  4035.862348   996858
# 3                      21    3895      33974  4639   22  1803.285714    37869

# %%
##jumlah perental pertahun dan bulan
day_df.groupby(by=["year", "month"]).agg({
    "dteday": "nunique",
    "casual": "sum",
    "registered": "sum",
    "Total": ["max", "min", "mean", "sum"]
})
# Out:
#                 dteday casual registered Total
#                nunique    sum        sum   max   min         mean     sum
# year month
# 0    April          30  22346      72524  5312   795  3162.333333   94870
#      August         31  28842     107849  5895  1115  4409.387097  136691
#      December       31   8448      78875  3940   705  2816.870968   87323
#      February       28   6242      41973  2927  1005  1721.964286   48215
#      January        31   3073      35116  1985   431  1231.903226   38189
#      July           31  36452     104889  6043  3285  4559.387097  141341
#      June           30  30612     112900  5515  3767  4783.733333  143512
#      March          31  12826      51219  3239   605  2065.967742   64045
#      May            31  31050     104771  5805  2633  4381.322581  135821
#      November       30  15594      86573  4486  1495  3405.566667  102167
#      October        31  25222      98289  5511   627  3984.225806  123511
#      September      30  26545     100873  5423  1842  4247.266667  127418
# 1    April          30  38456     135768  7460  1027  5807.466667  174224
#      August         31  43197     171306  7865  4549  6919.451613  214503
#      December       31  13245     110468  6606   441  3990.741935  123713
#      February       29   8721      94416  5062  1529  3556.448276  103137
#      January        31   8969      87775  4521  1301  3120.774194   96744
#      July           31  41705     161902  8173  4459  6567.967742  203607
#      June           30  43294     159536  8120  4127  6761.000000  202830
#      March          31  31618     133257  8362  3194  5318.548387  164875
#      May            31  44235     151630  8294  2843  6318.225806  195865
#      November       30  21009     131655  6852  2277  5088.800000  152664
#      October        31  34538     164303  8156    22  6414.225806  198841
#      September      30  43778     174795  8714  4073  7285.766667  218573

# %% [markdown]
# ### Explore HOUR

# %%
hour_df.describe(include='all')
# Out:
#            instant                         dteday season   year         month  \
# count   17379.0000                          17379  17379  17379  17379.000000
# unique         NaN                            NaN      4      2           NaN
# top            NaN                            NaN   Fall      1           NaN
# freq           NaN                            NaN   4496   8734           NaN
# mean     8690.0000  2012-01-02 04:08:34.552045568    NaN    NaN      6.537775
# min         1.0000            2011-01-01 00:00:00    NaN    NaN      1.000000
# 25%      4345.5000            2011-07-04 00:00:00    NaN    NaN      4.000000
# 50%      8690.0000            2012-01-02 00:00:00    NaN    NaN      7.000000
# 75%     13034.5000            2012-07-02 00:00:00    NaN    NaN     10.000000
# max     17379.0000            2012-12-31 00:00:00    NaN    NaN     12.000000
# std      5017.0295                            NaN    NaN    NaN      3.438776
#
#                 hour weekday   workingday weather_situation          temp  \
# count   17379.000000   17379        17379             17379  17379.000000
# unique           NaN       7            2                 1           NaN
# top              NaN  Sunday  Working Day           Unknown           NaN
# freq             NaN    2512        11865             17379           NaN
# mean       11.546752     NaN          NaN               NaN      0.496987
# min         0.000000     NaN          NaN               NaN      0.020000
# 25%         6.000000     NaN          NaN               NaN      0.340000
# 50%        12.000000     NaN          NaN               NaN      0.500000
# 75%        18.000000     NaN          NaN               NaN      0.660000
# max        23.000000     NaN          NaN               NaN      1.000000
# std         6.914405     NaN          NaN               NaN      0.192556
#
#            temp_feel      humidity     windspeed        casual    registered  \
# count   17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        0.475775      0.627229      0.190098     35.676218    153.786869
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         0.333300      0.480000      0.104500      4.000000     34.000000
# 50%         0.484800      0.630000      0.194000     17.000000    115.000000
# 75%         0.621200      0.780000      0.253700     48.000000    220.000000
# max         1.000000      1.000000      0.850700    367.000000    886.000000
# std         0.171850      0.192930      0.122340     49.305030    151.357286
#
#                Total
# count   17379.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean      189.463088
# min         1.000000
# 25%        40.000000
# 50%       142.000000
# 75%       281.000000
# max       977.000000
# std       181.387599

# %%
##jam rental
hour_df.groupby(by="hour").agg({
    "dteday": "nunique",
    "casual": "sum",
    "registered": "sum",
    "Total": ["max", "min", "mean", "sum"]
})
# Out:
#       dteday casual registered Total
#      nunique    sum        sum   max min        mean     sum
# hour
# 0        726   7375      31755   283   2   53.898072   39130
# 1        724   4709      19455   168   1   33.375691   24164
# 2        715   3412      12940   132   1   22.869930   16352
# 3        697   1893       6281    79   1   11.727403    8174
# 4        697    874       3554    28   1    6.352941    4428
# 5        717   1012      13249    66   1   19.889819   14261
# 6        725   3017      52115   213   1   76.044138   55132
# 7        727   8037     146134   596   1  212.064649  154171
# 8        727  15761     245240   839   5  359.011004  261001
# 9        727  22458     136980   426  14  219.309491  159438
# 10       727  33789      92468   539   8  173.668501  126257
# 11       727  43286     108034   663  10  208.143054  151320
# 12       728  49718     134696   776   3  253.315934  184414
# 13       729  52713     132206   760  11  253.661180  184919
# 14       729  55089     120563   750  12  240.949246  175652
# 15       729  54606     128543   750   7  251.233196  183149
# 16       730  53834     173914   783  11  311.983562  227748
# 17       730  54220     282640   976  15  461.452055  336860
# 18       728  44496     265276   977  23  425.510989  309772
# 19       728  35505     191284   743  11  311.523352  226789
# 20       728  26378     138172   567  11  226.030220  164550
# 21       728  20570     104875   584   6  172.314560  125445
# 22       728  16200      79412   502   9  131.335165   95612
# 23       728  11065      52876   256   2   87.831044   63941

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana performa tipe konsumen pada bike sharing berdasarkan hari?

# %%
ren_cas_df = hour_df.groupby("weekday").casual.sum().sort_values(ascending=False).reset_index()
ren_cas_df
# Out:
#      weekday  casual
# 0     Sunday  153852
# 1     Monday  140521
# 2   Saturday   78238
# 3    Tuesday   70784
# 4     Friday   61460
# 5  Wednesday   57843
# 6   Thursday   57319

# %%
ren_reg_df = hour_df.groupby("weekday").registered.sum().sort_values(ascending=False).reset_index()
ren_reg_df
# Out:
#      weekday  registered
# 0     Friday      423935
# 1   Thursday      415729
# 2  Wednesday      411266
# 3   Saturday      409552
# 4    Tuesday      384719
# 5     Sunday      323955
# 6     Monday      303506

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="casual", y="weekday", data=ren_cas_df, palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Performing Casual Rental by Day", loc="center", fontsize=15)
ax[0].tick_params(axis ='y', labelsize=12)

sns.barplot(x="registered", y="weekday", data=ren_reg_df, palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Performing Registered Rental by Day", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)

plt.suptitle("Performing Casual and Registered Rental by Day", fontsize=20)
plt.show()
# Out:
# <ipython-input-55-4e2f8f834616>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="casual", y="weekday", data=ren_cas_df, palette=colors, ax=ax[0])
# <ipython-input-55-4e2f8f834616>:5: UserWarning:
# The palette list has fewer values (5) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x="casual", y="weekday", data=ren_cas_df, palette=colors, ax=ax[0])
# <ipython-input-55-4e2f8f834616>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="registered", y="weekday", data=ren_reg_df, palette=colors, ax=ax[1])
# <ipython-input-55-4e2f8f834616>:11: UserWarning:
# The palette list has fewer values (5) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x="registered", y="weekday", data=ren_reg_df, palette=colors, ax=ax[1])

# %% [markdown]
# pada visualisasi diatas dapat dilihat bahwa rental pada casual user terbanyak pada hari minggu, sedangkan rental pada registered user terbanyak pada dari jumat.

# %% [markdown]
# ### Pertanyaan 2: Bagaimana performa bike sharing tiap bulan?

# %%
bymonth_df = hour_df.groupby("month").Total.sum().sort_values(ascending=False).reset_index()

plt.figure(figsize=(15, 5))

sns.barplot(
    y="Total",
    x="month",
    data=bymonth_df.sort_values(by="month", ascending=False),
    palette=colors
)
plt.title("Number of Rental by Month", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.show()
# Out:
# <ipython-input-56-60de07d54ba7>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# <ipython-input-56-60de07d54ba7>:5: UserWarning:
# The palette list has fewer values (5) than needed (12) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(

# %% [markdown]
# dapat diketahui bahwa rental terbanyak pada bulan September, Agustus, dan Juni.

# %% [markdown]
# ### Pertanyaan 1: Bagaimana Performa bike sharing pada tiap musim?

# %%
fig, ax = plt.subplots(figsize=(20,5))
sns.pointplot(data=hour_df, x='hour', y='Total', hue='season', ax=ax)
ax.set(title='Count of bikes during season')
# Out:
# [Text(0.5, 1.0, 'Count of bikes during season')]

# %% [markdown]
#  diatas dapat dilihat bahwa jumlah rental terbanyak terdapat pada musim gugur pada jam 17.00. Pada musim lainnya, jumlah rental terbanyak juga terdapat pada jam 17.00. Sedangkan jumlah rental terlihat ada penurunan ketika menjelang tengah malam hingga pagi hari.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Tipe konsumen casual terbanyak pada hari minggu, sedangkan registered pada hari jumat.
# - Bulan September merupakan bulan rental tertinggi.
# - Rental terbanyak pada musim gugur.
